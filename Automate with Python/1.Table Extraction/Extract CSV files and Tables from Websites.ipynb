# %%
import pandas as pd

# %% [markdown]
# # Read a .csv from a URL with Pandas

# %% [markdown]
# Target website: https://www.football-data.co.uk/data.php

# %%
# reading 1 csv file from the website
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')

# %%
df_argentina_fc = pd.read_csv('https://www.football-data.co.uk/new/ARG.csv')

# %%
df_argentina_fc.head()
# Out:
#      Country             League     Season        Date   Time  \
# 0  Argentina  Liga Profesional   2012/2013  03/08/2012  23:00
# 1  Argentina  Liga Profesional   2012/2013  04/08/2012  01:10
# 2  Argentina  Liga Profesional   2012/2013  04/08/2012  18:10
# 3  Argentina  Liga Profesional   2012/2013  04/08/2012  20:10
# 4  Argentina  Liga Profesional   2012/2013  04/08/2012  22:15
#
#               Home               Away  HG  AG Res    PH    PD    PA  MaxH  \
# 0  Arsenal Sarandi  Union de Santa Fe   1   0   H  1.90  3.39  5.03  1.90
# 1  Velez Sarsfield     Argentinos Jrs   3   0   H  2.00  3.24  4.55  2.18
# 2      Racing Club       Atl. Rafaela   1   1   D  1.91  3.34  5.09  2.00
# 3   Colon Santa FE              Lanus   1   0   H  2.50  3.16  3.27  2.54
# 4          Quilmes       Boca Juniors   3   0   H  3.18  3.13  2.58  3.37
#
#    MaxD  MaxA  AvgH  AvgD  AvgA
# 0  3.50  5.68  1.76  3.30  4.74
# 1  3.30  4.62  1.97  3.12  3.96
# 2  3.40  5.09  1.91  3.22  4.05
# 3  3.16  3.36  2.39  2.99  3.04
# 4  3.13  2.58  3.07  2.99  2.38

# %%
# showing dataframe
df_premier21.head()
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# 1     1.93     2.10     1.79
# 2     2.19     1.79     2.12
# 3     1.93     2.06     1.82
# 4     1.90     2.03     1.86
#
# [5 rows x 106 columns]

# %%
# rename columns
df_premier21 = df_premier21.rename(columns={'Date':'date',
                                            'HomeTeam':'home_team',
                                            'AwayTeam':'away_team',
                                            'FTHG': 'home_goals',
                                            'FTAG': 'away_goals'})

# %%
# show dataframe
df_premier21
# Out:
#     Div        date   Time       home_team       away_team  home_goals  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal           2
# 1    E0  14/08/2021  12:30      Man United           Leeds           5
# 2    E0  14/08/2021  15:00         Burnley        Brighton           1
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace           3
# 4    E0  14/08/2021  15:00         Everton     Southampton           3
# ..   ..         ...    ...             ...             ...         ...
# 210  E0  23/01/2022  14:00         Arsenal         Burnley           0
# 211  E0  23/01/2022  14:00  Crystal Palace       Liverpool           1
# 212  E0  23/01/2022  14:00       Leicester        Brighton           1
# 213  E0  23/01/2022  16:30         Chelsea       Tottenham           2
# 214  E0  05/02/2022  18:00         Burnley         Watford           0
#
#      away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# 0             0   H     1     0  ...     1.62  0.50      1.75      2.05
# 1             1   H     1     0  ...     2.25 -1.00      2.05      1.75
# 2             2   A     1     0  ...     1.62  0.25      1.79      2.15
# 3             0   H     2     0  ...     1.94 -1.50      2.05      1.75
# 4             1   H     0     1  ...     1.67 -0.50      2.05      1.88
# ..          ...  ..   ...   ...  ...      ...   ...       ...       ...
# 210           0   D     0     0  ...     2.32 -1.50      1.92      2.01
# 211           3   A     0     2  ...     2.11  1.00      1.96      1.97
# 212           1   D     0     0  ...     2.10  0.00      1.92      2.01
# 213           0   H     0     0  ...     1.84 -0.75      1.99      1.94
# 214           0   D     0     0  ...     1.73 -0.25      1.90      2.00
#
#      PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.81   2.13     2.05     2.17     1.80     2.09
# 1     2.17   1.77     2.19     1.93     2.10     1.79
# 2     1.81   2.14     1.82     2.19     1.79     2.12
# 3     2.12   1.81     2.16     1.93     2.06     1.82
# 4     2.05   1.88     2.08     1.90     2.03     1.86
# ..     ...    ...      ...      ...      ...      ...
# 210   1.93   2.00     1.93     2.11     1.90     1.98
# 211   1.94   1.97     2.07     2.02     1.92     1.96
# 212   1.93   1.99     1.94     2.13     1.87     2.01
# 213   1.97   1.95     2.03     2.07     1.96     1.92
# 214   1.89   2.03     1.93     2.07     1.87     2.01
#
# [215 rows x 106 columns]

# %% [markdown]
# # Read HTML

# %% [markdown]
# Target Website: https://es.wikipedia.org/wiki/Anexo:Episodios_de_Game_of_Thrones

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.0-cp310-cp310-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-4.9.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
game_of_thrones = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Episodios_de_Game_of_Thrones')

# %%
len(game_of_thrones)
# Out:
# 9

# %%
game_of_thrones[1].head()
# Out:
#    N.º en serie  N.º en temp.                                   Título  \
# 0             1             1                       «Winter Is Coming»
# 1             2             2                          «The Kingsroad»
# 2             3             3                              «Lord Snow»
# 3             4             4  «Cripples, Bastards, and Broken Things»
# 4             5             5                  «The Wolf and the Lion»
#
#      Dirigido por                  Escrito por Fecha de emisión original  \
# 0  Tim Van Patten  David Benioff & D. B. Weiss       17 de abril de 2011
# 1  Tim Van Patten  David Benioff & D. B. Weiss       24 de abril de 2011
# 2      Brian Kirk  David Benioff & D. B. Weiss         1 de mayo de 2011
# 3      Brian Kirk                 Bryan Cogman         8 de mayo de 2011
# 4      Brian Kirk  David Benioff & D. B. Weiss        15 de mayo de 2011
#
#   Audiencia (millones)
# 0             2,22[9]​
# 1            2,20[10]​
# 2            2,44[11]​
# 3            2,45[12]​
# 4            2,58[13]​
